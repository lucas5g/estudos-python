# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = sns.load_dataset('tips')

# %%
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style("white")
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.set_style("ticks")
sns.countplot(x="sex", data=tips, palette="deep")
# Out:
# /tmp/ipykernel_937924/3900462564.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex", data=tips, palette="deep")
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="sex", data=tips)
sns.despine()

# %%
sns.countplot(x="sex", data=tips)
sns.despine(left=True)

# %%
plt.figure(figsize=(12,3))
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x="total_bill", y="tip",aspect=4, data=tips)

# %%
sns.set_context("poster", font_scale=4)
sns.countplot(x="sex", data=tips, palette="coolwarm")
# Out:
# /tmp/ipykernel_937924/3910244548.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex", data=tips, palette="coolwarm")
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.puppyplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sns.puppyplot()
#
# AttributeError: module 'seaborn' has no attribute 'puppyplot'
